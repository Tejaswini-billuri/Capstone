# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import random

# %%
pip install faker
# Out:
# Collecting faker
#   Downloading Faker-15.3.3-py3-none-any.whl (1.6 MB)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\dhara\python\lib\site-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\dhara\python\lib\site-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Installing collected packages: faker
# Successfully installed faker-15.3.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from faker import Faker
fake = Faker('en_IN')

# %% [markdown]
# # CUSTOMER TABLE

# %%
cust_fields= ['customerid','name','address','city','state','pincode','update_timestamp']

# %%
states = {'Bihar':['Patna','Muzaffarpur','Gaya'],
          'Karnataka':['Belgaum','Bengaluru','Mangalore','Mysore'],
          'Maharashtra':['Mumbai','Nagpur','Navi Mumbai','Pune'],
          'Tamil Nadu':['Chennai','Coimbatore','Madurai'],
          'Uttar Pradesh':['Agra','Greater Noida','Kanpur','Lucknow','Mathura'],
          'Odisha':['Bhubaneswar','Cuttack','Rourkela']}

# %%
customer = pd.DataFrame(columns=cust_fields,index=range(1,1001))
Faker.seed(10)
for i in range(1,1001):
    customer['customerid'][i]=i
    customer['name'][i]=fake.name()
    customer['address'][i]=fake.street_address()    
    customer['state'][i]=fake.random_element(states.keys())
    customer['city'][i]=fake.random_element(states[customer['state'][i]])
    customer['pincode'][i]=fake.postcode()
    customer['update_timestamp'][i]=fake.date_time_this_year()

# %%
customer = customer.reset_index(drop=True)

# %%
customer.head(40)
# Out:
#    customerid                name                    address         city  \
# 0           1     Aaryahi Khurana          774, Badal Street      Lucknow
# 1           2        Vaibhav Kade        47/245\nKari Street       Mysore
# 2           3        Trisha Yadav        H.No. 87, Keer Marg         Gaya
# 3           4        Romil Taneja           12/69, Rama Path      Belgaum
# 4           5          Pihu Devan          82/14, Dora Chowk    Bengaluru
# 5           6         Shalv Yadav            147\nManne Marg       Mysore
# 6           7          Ivan Konda          26\nMaster Circle         Pune
# 7           8           Heer Bali  H.No. 12, Ramanathan Zila   Coimbatore
# 8           9          Aarna Gala               35/903, Mani      Cuttack
# 9          10        Reyansh Bumb             596\nGill Ganj      Belgaum
# 10         11          Alia Salvi       H.No. 95, Ratti Zila  Bhubaneswar
# 11         12         Yasmin Basu       H.No. 45, Kala Chowk    Mangalore
# 12         13     Stuvan Seshadri                 77\nKhatri         Gaya
# 13         14     Advik Rajagopal         51/695\nRaman Road    Bengaluru
# 14         15          Aaina Char            06/35\nChandran      Mathura
# 15         16          Kismat Ray         195, Aurora Street     Rourkela
# 16         17          Renee Keer        79/256\nMammen Path      Lucknow
# 17         18           Jiya Kala        60/90\nDugal Street      Belgaum
# 18         19         Dhanuk Gera            22, Tailor Marg   Coimbatore
# 19         20         Divit Issac             164, Loke Road  Bhubaneswar
# 20         21          Nitya Brar          31/871\nZachariah      Madurai
# 21         22      Dhanuk Iyengar      H.No. 652, Gola Nagar         Pune
# 22         23      Mannat Mahajan      02/01\nTripathi Nagar         Gaya
# 23         24      Badal Majumdar    H.No. 697, Ganesh Chowk      Belgaum
# 24         25         Divij Karpe            418, Bobal Road         Gaya
# 25         26           Diya Bora      09/038, Chhabra Nagar    Mangalore
# 26         27        Anahi Chahal      H.No. 692, Saha Chowk  Bhubaneswar
# 27         28         Anaya Sarna                 785\nSodhi      Lucknow
# 28         29             Eva Lal            91, Bhatt Nagar        Patna
# 29         30           Zara Kari       H.No. 22\nMagar Marg     Rourkela
# 30         31     Vedika Chandran        29/98, Banik Street      Cuttack
# 31         32     Mohanlal Chawla  H.No. 49, Brahmbhatt Road  Muzaffarpur
# 32         33      Yuvraj  Saxena              21\nKala Marg        Patna
# 33         34       Kaira Khurana           16, Tandon Chowk       Mysore
# 34         35       Alisha Chacko            79, Jaggi Chowk         Pune
# 35         36  Umang Ramachandran        08/90, Butala Nagar   Coimbatore
# 36         37        Armaan Anand         77/506, Dayal Path        Patna
# 37         38        Stuvan Dutta        59/460\nKhosla Zila     Rourkela
# 38         39          Ira Shukla             H.No. 30\nKala  Bhubaneswar
# 39         40     Kashvi Varghese             08, Konda Road         Gaya
#
#             state pincode     update_timestamp
# 0   Uttar Pradesh  135062  2022-08-23 06:08:38
# 1       Karnataka  090323  2022-04-28 14:51:54
# 2           Bihar  823630  2022-01-13 07:54:02
# 3       Karnataka  723566  2022-06-23 01:21:38
# 4       Karnataka  755630  2022-07-31 14:22:30
# 5       Karnataka  384879  2022-07-14 03:13:09
# 6     Maharashtra  287160  2022-01-02 02:22:53
# 7      Tamil Nadu  768754  2022-11-03 07:29:40
# 8          Odisha  146341  2022-01-18 22:56:58
# 9       Karnataka  631478  2022-10-08 13:57:01
# 10         Odisha  696631  2022-10-27 22:08:00
# 11      Karnataka  487846  2022-06-21 12:26:10
# 12          Bihar  629691  2022-08-20 06:46:48
# 13      Karnataka  418039  2022-10-17 07:05:22
# 14  Uttar Pradesh  090095  2022-06-04 04:34:17
# 15         Odisha  167950  2022-02-26 12:14:30
# 16  Uttar Pradesh  316202  2022-09-06 13:44:01
# 17      Karnataka  195240  2022-06-03 17:11:59
# 18     Tamil Nadu  229628  2022-09-07 05:37:37
# 19         Odisha  897938  2022-04-23 20:48:01
# 20     Tamil Nadu  451398  2022-07-26 07:33:47
# 21    Maharashtra  032433  2022-04-06 16:28:02
# 22          Bihar  161062  2022-08-31 09:21:15
# 23      Karnataka  775124  2022-04-09 07:52:43
# 24          Bihar  495094  2022-09-04 16:33:33
# 25      Karnataka  205817  2022-04-27 07:53:58
# 26         Odisha  872079  2022-06-01 05:11:55
# 27  Uttar Pradesh  552070  2022-09-19 15:40:40
# 28          Bihar  637911  2022-01-27 08:12:27
# 29         Odisha  326389  2022-07-10 01:53:10
# 30         Odisha  130722  2022-05-23 12:27:15
# 31          Bihar  550548  2022-10-29 10:54:05
# 32          Bihar  216810  2022-07-22 01:00:57
# 33      Karnataka  779764  2022-08-07 05:15:56
# 34    Maharashtra  885742  2022-04-02 00:46:08
# 35     Tamil Nadu  302750  2022-07-15 18:49:01
# 36          Bihar  023187  2022-10-29 19:18:03
# 37         Odisha  767512  2022-08-14 14:39:00
# 38         Odisha  275616  2022-04-07 08:20:17
# 39          Bihar  322768  2022-03-16 02:04:50

# %% [markdown]
# # PRODUCT TABLE

# %%
product_master_fields = ['productid','productcode','productname','sku','rate','isactive']

# %%
product_initials = ['Patanjali','Himalaya','Dabur','Ashirvaad','Lotus','APD','Glorious','HUL','Living']
product_types = ['ata','seeds','Mix Fruits','rice','sweets','bags']

# %%
productname = ((a,b) for a in product_initials for b in product_types)
productlist=[]
for a,b in productname:
    productlist.append(a+ ' '+b)
print(productlist)
# Out:
# ['Patanjali ata', 'Patanjali seeds', 'Patanjali Mix Fruits', 'Patanjali rice', 'Patanjali sweets', 'Patanjali bags', 'Himalaya ata', 'Himalaya seeds', 'Himalaya Mix Fruits', 'Himalaya rice', 'Himalaya sweets', 'Himalaya bags', 'Dabur ata', 'Dabur seeds', 'Dabur Mix Fruits', 'Dabur rice', 'Dabur sweets', 'Dabur bags', 'Ashirvaad ata', 'Ashirvaad seeds', 'Ashirvaad Mix Fruits', 'Ashirvaad rice', 'Ashirvaad sweets', 'Ashirvaad bags', 'Lotus ata', 'Lotus seeds', 'Lotus Mix Fruits', 'Lotus rice', 'Lotus sweets', 'Lotus bags', 'APD ata', 'APD seeds', 'APD Mix Fruits', 'APD rice', 'APD sweets', 'APD bags', 'Glorious ata', 'Glorious seeds', 'Glorious Mix Fruits', 'Glorious rice', 'Glorious sweets', 'Glorious bags', 'HUL ata', 'HUL seeds', 'HUL Mix Fruits', 'HUL rice', 'HUL sweets', 'HUL bags', 'Living ata', 'Living seeds', 'Living Mix Fruits', 'Living rice', 'Living sweets', 'Living bags']

# %%
import math

# %%
product_master = pd.DataFrame(columns=product_master_fields,index=range(1,101))
Faker.seed(15)
for j in range(1,101):      
    product_master['productid'][j]=j
    product_master['productname'][j]= productlist[int(j+1)//2]
    if(j%2):
        product_master['productcode'][j]=fake.bothify('?##', letters='ABCDE')
        product_master['sku'][j] = str(fake.random_int(min=1, max=5)) + fake.bothify('?', letters=['KG'])
        product_master['rate'][j]=round(np.random.normal(1000,200))
    else:
        product_master['productcode'][j]=fake.bothify('?##', letters='FGHIJ')
        product_master['sku'][j] = str(fake.random_int(min=6, max=10)) + fake.bothify('?', letters=['KG'])
        product_master['rate'][j]=round(np.random.normal(1000,200))+round(np.random.normal(800,200))
        
    product_master['isactive'][j]=fake.boolean(chance_of_getting_true=80)

# %%
product_master.head(100)
# Out:
#     productid productcode           productname  sku  rate isactive
# 1           1         E30       Patanjali seeds  1KG  1188     True
# 2           2         G00       Patanjali seeds  8KG  1247     True
# 3           3         C57  Patanjali Mix Fruits  3KG   858     True
# 4           4         G53  Patanjali Mix Fruits  8KG  1640     True
# 5           5         D48        Patanjali rice  2KG  1149     True
# ..        ...         ...                   ...  ...   ...      ...
# 96         96         H36            Living ata  8KG  1979     True
# 97         97         C31          Living seeds  1KG  1153     True
# 98         98         F34          Living seeds  6KG  1310    False
# 99         99         A22     Living Mix Fruits  5KG  1080    False
# 100       100         F35     Living Mix Fruits  8KG  1595     True
#
# [100 rows x 6 columns]

# %% [markdown]
# # ORDER DETAILS

# %%
order_detail_fields = ['orderid','customerid','order_status_update_timestamp','order_status']

# %%
orders_Received = pd.DataFrame(columns=order_detail_fields, index = range(1,20001))
orders_InProgress = pd.DataFrame(columns=order_detail_fields, index = range(1,20001))
orders_Delivered = pd.DataFrame(columns=order_detail_fields, index = range(1,20001))

# %%
for i in range(1,20001):
    orders_Received['orderid'][i]=i
    orders_Received['customerid'][i]=fake.random_element(customer['customerid'])
    orders_Received['order_status_update_timestamp'][i]=fake.date_time_this_year()
    orders_Received['order_status']='Received'
    
for i in range(1,20001):
    orders_InProgress['orderid'][i]=i
    orders_InProgress['customerid'][i]=orders_Received['customerid'][i]
    orders_InProgress['order_status_update_timestamp'][i]=orders_Received['order_status_update_timestamp'][i]+timedelta(seconds=fake.random_int(min=1, max=86400))
    orders_InProgress['order_status'][i]='InProgress'
    
for i in range(1,20001):
    orders_Delivered['orderid'][i]=i
    orders_Delivered['customerid'][i]=orders_Received['customerid'][i]
    orders_Delivered['order_status_update_timestamp'][i]=orders_InProgress['order_status_update_timestamp'][i]+timedelta(seconds=fake.random_int(min=1, max=86400))
    orders_Delivered['order_status'][i]='Delivered'

# %%
order_details = pd.concat([orders_Received,orders_InProgress,orders_Delivered])

# %%
order_details.sort_values(by=["orderid"])
# Out:
#       orderid customerid order_status_update_timestamp order_status
# 1           1         50           2022-11-19 16:48:54     Received
# 1           1         50           2022-11-20 03:32:40   InProgress
# 1           1         50           2022-11-20 14:22:07    Delivered
# 2           2        990           2022-03-30 02:00:36     Received
# 2           2        990           2022-03-30 12:11:04   InProgress
# ...       ...        ...                           ...          ...
# 19999   19999        691           2022-04-29 14:00:59     Received
# 19999   19999        691           2022-04-29 17:20:03   InProgress
# 20000   20000        324           2022-08-30 14:51:29   InProgress
# 20000   20000        324           2022-08-30 12:34:00     Received
# 20000   20000        324           2022-08-30 14:57:56    Delivered
#
# [60000 rows x 4 columns]

# %%
len(order_details['orderid'].unique())
# Out:
# 20000

# %% [markdown]
# # ORDER ITEMS

# %%
order_item_fields = ['orderid','productid','quantity']

# %%
order_items = pd.DataFrame(columns=order_item_fields, index = range(0,50000))

# %%
for i in range(0,50000):
    if(i<20000):
        order_items['orderid'][i]=i+1
    else:    
        order_items['orderid'][i]=fake.random_element(order_details['orderid'])
    order_items['productid'][i]=fake.random_element(product_master['productid'])
    order_items['quantity'][i]=fake.random_int(min=1, max=20)

# %%
for i in range(20000,50000):
    order_items['orderid'][i]=fake.random_element(order_details['orderid'])
    order_items['productid'][i]=fake.random_element(product_master['productid'])
    order_items['quantity'][i]=fake.random_int(min=1, max=20)

# %%
order_id =[]
productid = []
qnty = []

order_items = pd.DataFrame(columns = ['orderid','productid','quantity'])

for i in range(1,20001):
    x = list(range(1, 51))     
    for j in range(0,random.randint(1,5)):
        pri = random.choice(x)
        order_id.append(i)
        productid.append(pri)
        x.remove(pri)
        qnty.append(random.randint(1,5))

order_items = pd.DataFrame(list(zip(order_id,productid,qnty)),columns=['orderid','productid','quantity'])

# %%
order_items.sort_values(by=['orderid'])
# Out:
#        orderid  productid  quantity
# 0            1         26         4
# 1            1         25         1
# 2            2         32         4
# 3            2         33         5
# 4            3         22         1
# ...        ...        ...       ...
# 59805    19998         20         3
# 59803    19998         27         1
# 59806    19998         36         1
# 59807    19999          7         3
# 59808    20000         12         1
#
# [59809 rows x 3 columns]

# %%
len(order_items['orderid'].unique())
# Out:
# 20000

# %% [markdown]
# # LOAD DATA

# %%
import pymysql

# Connect to the database
connection = pymysql.connect(host='34.148.88.4',
                         user='root',
                         password='tejaswini',
                         db='oltp_schema')

# create cursor
cursor=connection.cursor()

# %%
from sqlalchemy import create_engine

# create sqlalchemy engine
engine = create_engine("mysql+pymysql://root:tejaswini@34.148.88.4/oltp_schema")

# %%
customer.to_sql('customer_master', con = engine, if_exists = 'append',index=False)
# Out:
# 1000

# %%
product_master.to_sql('product_master', con = engine, if_exists = 'append',index=False)
# Out:
# 100

# %%
order_details.to_sql('order_details', con = engine, if_exists = 'append',index=False)
# Out:
# 60000

# %%
order_items.to_sql('order_items', con = engine, if_exists = 'append',index=False)
# Out:
# 59809
